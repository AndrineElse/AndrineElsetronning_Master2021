# %% [markdown]
# # Testing out sktime-dl
#
# There is an issue with the sktime-dl library being dependant on an old sktime version.

# %%
from sktime_dl.deeplearning import CNNClassifier, InceptionTimeClassifier, ResNetClassifier
import numpy as np
import pandas as pd
import os
import sys
import time as time
module_path = os.path.abspath(os.path.join('..'))
sys.path.insert(1, module_path + '/src')
import utility

import sktime
from sktime.utils.data_io import load_from_tsfile_to_dataframe

import matplotlib.pyplot as plt

from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix


from matplotlib.font_manager import FontProperties
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns
import matplotlib
font = FontProperties(fname = module_path + '/src/visualization/CharterRegular.ttf', size = 10, weight = 1000)
font_small = FontProperties(fname = module_path + '/src/visualization/CharterRegular.ttf', size = 7, weight = 1000)
color_map = ['#8ECAE6', '#219EBC', '#023047', '#FFB703', '#FB8500']
class_names = ['crackle', 'no-crackle']

# %%
X, y = load_from_tsfile_to_dataframe(module_path + '/data/ts_files/crackleNoCrackle_no_rms.ts')
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

labels_train, counts_train = np.unique(y_train, return_counts=True)
print(labels_train, counts_train)
labels_test, counts_test = np.unique(y_test, return_counts=True)
print(labels_test, counts_test)
# Out:
# ['0' '1'] [3241 1757]
# ['0' '1'] [1106  561]

# %% [markdown]
# ## Comments about time and performance
#
# **InceptionTime** with default parameters used 6528 seconds to fit the data with only 10 samples
# Testing ways to shorten this time:
# * only 5 epochs --> result: Fitting time :  34 s, predicting time 689 s
# * * This wont run on the entire dataset it seems
#
# **ResNetClassifier**
# Fitting time for fixed 3000 : 5876 s
# The accu

# %%
SMALL_NB_EPOCHS = 100
start = time.time()
network=CNNClassifier(nb_epochs=SMALL_NB_EPOCHS, verbose = True)
#network=InceptionTimeClassifier(nb_epochs=SMALL_NB_EPOCHS)
#network=ResNetClassifier(nb_epochs=SMALL_NB_EPOCHS)
network.fit(X_train, y_train)
print(f'Fitting time : {time.time() - start}')
start = time.time()
y_pred = network.predict(X_test)
print(f'Predicting time : {time.time() - start}')
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 20000, 1)]        0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 19994, 6)          48
# _________________________________________________________________
# average_pooling1d_4 (Average (None, 6664, 6)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 6658, 12)          516
# _________________________________________________________________
# average_pooling1d_5 (Average (None, 2219, 12)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 26628)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 53258
# =================================================================
# Total params: 53,822
# Trainable params: 53,822
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 313/313 [==============================] - 34s 101ms/step - loss: 0.4948 - accuracy: 0.6517
# Epoch 2/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6427
# Epoch 3/100
# 313/313 [==============================] - 33s 105ms/step - loss: 0.5000 - accuracy: 0.6463
# Epoch 4/100
# 313/313 [==============================] - 33s 104ms/step - loss: 0.5000 - accuracy: 0.6546
# Epoch 5/100
# 313/313 [==============================] - 33s 106ms/step - loss: 0.5000 - accuracy: 0.6413
# Epoch 6/100
# 313/313 [==============================] - 33s 104ms/step - loss: 0.5000 - accuracy: 0.6521
# Epoch 7/100
# 313/313 [==============================] - 32s 104ms/step - loss: 0.5000 - accuracy: 0.6536
# Epoch 8/100
# 313/313 [==============================] - 33s 104ms/step - loss: 0.5000 - accuracy: 0.6556
# Epoch 9/100
# 313/313 [==============================] - 32s 103ms/step - loss: 0.5000 - accuracy: 0.6384
# Epoch 10/100
# 313/313 [==============================] - 33s 104ms/step - loss: 0.5000 - accuracy: 0.6401
# Epoch 11/100
# 313/313 [==============================] - 34s 108ms/step - loss: 0.5000 - accuracy: 0.6460
# Epoch 12/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6559
# Epoch 13/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6596
# Epoch 14/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6414
# Epoch 15/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6542
# Epoch 16/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6525
# Epoch 17/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6377
# Epoch 18/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6567
# Epoch 19/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6391
# Epoch 20/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6539
# Epoch 21/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6507
# Epoch 22/100
# 313/313 [==============================] - 31s 101ms/step - loss: 0.5000 - accuracy: 0.6490
# Epoch 23/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6475
# Epoch 24/100
# 313/313 [==============================] - 32s 102ms/step - loss: 0.5000 - accuracy: 0.6529
# Epoch 25/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6438
# Epoch 26/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6547
# Epoch 27/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6432
# Epoch 28/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6434
# Epoch 29/100
# 313/313 [==============================] - 31s 101ms/step - loss: 0.5000 - accuracy: 0.6509
# Epoch 30/100
# 313/313 [==============================] - 31s 101ms/step - loss: 0.5000 - accuracy: 0.6606
# Epoch 31/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6592
# Epoch 32/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6559
# Epoch 33/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6491
# Epoch 34/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6530
# Epoch 35/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6491
# Epoch 36/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6440
# Epoch 37/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6413
# Epoch 38/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6490
# Epoch 39/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6431
# Epoch 40/100
# 313/313 [==============================] - 32s 102ms/step - loss: 0.5000 - accuracy: 0.6565
# Epoch 41/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6452
# Epoch 42/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6436
# Epoch 43/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6515
# Epoch 44/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6527
# Epoch 45/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6447
# Epoch 46/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6498
# Epoch 47/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6550
# Epoch 48/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6458
# Epoch 49/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6558
# Epoch 50/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6469
# Epoch 51/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6479
# Epoch 52/100
# 313/313 [==============================] - 32s 102ms/step - loss: 0.5000 - accuracy: 0.6389
# Epoch 53/100
# 313/313 [==============================] - 31s 101ms/step - loss: 0.5000 - accuracy: 0.6346
# Epoch 54/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6328
# Epoch 55/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6573
# Epoch 56/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6412
# Epoch 57/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6505
# Epoch 58/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6536
# Epoch 59/100
# 313/313 [==============================] - 31s 101ms/step - loss: 0.5000 - accuracy: 0.6518
# Epoch 60/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6466
# Epoch 61/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6505
# Epoch 62/100
# 313/313 [==============================] - 32s 103ms/step - loss: 0.5000 - accuracy: 0.6359
# Epoch 63/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6522
# Epoch 64/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6502
# Epoch 65/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6487
# Epoch 66/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6536
# Epoch 67/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6504
# Epoch 68/100
# 313/313 [==============================] - 31s 98ms/step - loss: 0.5000 - accuracy: 0.6442
# Epoch 69/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6494
# Epoch 70/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6523
# Epoch 71/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6502
# Epoch 72/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6571
# Epoch 73/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6504
# Epoch 74/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6414
# Epoch 75/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6544
# Epoch 76/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6617
# Epoch 77/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6423
# Epoch 78/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6406
# Epoch 79/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6477
# Epoch 80/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6461
# Epoch 81/100
# 313/313 [==============================] - 33s 105ms/step - loss: 0.5000 - accuracy: 0.6446
# Epoch 82/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6525
# Epoch 83/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6570
# Epoch 84/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6428
# Epoch 85/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6479
# Epoch 86/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6598
# Epoch 87/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6443
# Epoch 88/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6525
# Epoch 89/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6542
# Epoch 90/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6585
# Epoch 91/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6477
# Epoch 92/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6620
# Epoch 93/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6497
# Epoch 94/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6301
# Epoch 95/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6439
# Epoch 96/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6492
# Epoch 97/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6375
# Epoch 98/100
# 313/313 [==============================] - 31s 100ms/step - loss: 0.5000 - accuracy: 0.6390
# Epoch 99/100
# 313/313 [==============================] - 31s 99ms/step - loss: 0.5000 - accuracy: 0.6433
# Epoch 100/100
# 313/313 [==============================] - 32s 101ms/step - loss: 0.5000 - accuracy: 0.6595
# Fitting time : 3193.1049144268036
# Predicting time : 4.5260984897613525

# %%
#print(classification_report(y_pred, y_test))
cm = confusion_matrix(y_test, y_pred)
f, ax = plt.subplots(1,1) # 1 x 1 array , can also be any other size
f.set_size_inches(5, 5)

cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

colors_2 = ['#FFFFFF', color_map[0]]
cmap_name = 'my colormap'
cm_map = LinearSegmentedColormap.from_list(cmap_name, colors_2)

ax = sns.heatmap(cm, annot=True,
            fmt='.2%', cmap=cm_map, xticklabels=class_names,yticklabels=class_names )
cbar = ax.collections[0].colorbar
for label in ax.get_yticklabels() :
    label.set_fontproperties(font_small)
for label in ax.get_xticklabels() :
    label.set_fontproperties(font_small)
ax.set_ylabel('True Label', fontproperties = font)
ax.set_xlabel('Predicted Label', fontproperties = font)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 0)

for child in ax.get_children():
    if isinstance(child, matplotlib.text.Text):
        child.set_fontproperties(font)
for l in cbar.ax.yaxis.get_ticklabels():
    l.set_fontproperties(font_small)

# %% [markdown]
# # Saving and loading
#
# NB ! The loading part will need some more work

# %%
network.model.save(module_path + '/src/models/resNet_3000_crackle_no_crackle.h5')

# %%
from keras.models import load_model

test = load_model(module_path + '/src/models/models_h5/temp_model.h5')

# %%
import sktime_dl.deeplearning

help(sktime_dl.deeplearning)
# Out:
# Help on package sktime_dl.deeplearning in sktime_dl:
#
# NAME
#     sktime_dl.deeplearning
#
# PACKAGE CONTENTS
#     base (package)
#     cnn (package)
#     encoder (package)
#     fcn (package)
#     inceptiontime (package)
#     lstm (package)
#     mcdcnn (package)
#     mcnn (package)
#     mlp (package)
#     resnet (package)
#     rnn (package)
#     tests (package)
#     tlenet (package)
#     twiesn (package)
#
# CLASSES
#     sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier(sktime.classification.base.BaseClassifier)
#         sktime_dl.deeplearning.cnn._classifier.CNNClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.cnn._base.CNNNetwork)
#         sktime_dl.deeplearning.encoder._classifier.EncoderClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.encoder._base.EncoderNetwork)
#         sktime_dl.deeplearning.fcn._classifier.FCNClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.fcn._base.FCNNetwork)
#         sktime_dl.deeplearning.inceptiontime._classifier.InceptionTimeClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.inceptiontime._base.InceptionTimeNetwork)
#         sktime_dl.deeplearning.mcdcnn._classifier.MCDCNNClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.mcdcnn._base.MCDCNNNetwork)
#         sktime_dl.deeplearning.mcnn._classifier.MCNNClassifier
#         sktime_dl.deeplearning.mlp._classifier.MLPClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.mlp._base.MLPNetwork)
#         sktime_dl.deeplearning.resnet._classifier.ResNetClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.resnet._base.ResNetNetwork)
#         sktime_dl.deeplearning.tlenet._classifier.TLENETClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.tlenet._base.TLENETNetwork)
#         sktime_dl.deeplearning.twiesn._classifier.TWIESNClassifier
#     sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork(builtins.object)
#         sktime_dl.deeplearning.rnn._regressor.SimpleRNNRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork)
#     sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor(sktime.regression.base.BaseRegressor, sklearn.base.RegressorMixin)
#         sktime_dl.deeplearning.cnn._regressor.CNNRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.cnn._base.CNNNetwork)
#         sktime_dl.deeplearning.encoder._regressor.EncoderRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.encoder._base.EncoderNetwork)
#         sktime_dl.deeplearning.fcn._regressor.FCNRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.fcn._base.FCNNetwork)
#         sktime_dl.deeplearning.inceptiontime._regressor.InceptionTimeRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.inceptiontime._base.InceptionTimeNetwork)
#         sktime_dl.deeplearning.lstm._regressor.LSTMRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.lstm._base.LSTMNetwork)
#         sktime_dl.deeplearning.mcdcnn._regressor.MCDCNNRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.mcdcnn._base.MCDCNNNetwork)
#         sktime_dl.deeplearning.mlp._regressor.MLPRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.mlp._base.MLPNetwork)
#         sktime_dl.deeplearning.resnet._regressor.ResNetRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.resnet._base.ResNetNetwork)
#         sktime_dl.deeplearning.rnn._regressor.SimpleRNNRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork)
#         sktime_dl.deeplearning.tlenet._regressor.TLENETRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.tlenet._base.TLENETNetwork)
#     sktime_dl.deeplearning.cnn._base.CNNNetwork(sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork)
#         sktime_dl.deeplearning.cnn._classifier.CNNClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.cnn._base.CNNNetwork)
#         sktime_dl.deeplearning.cnn._regressor.CNNRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.cnn._base.CNNNetwork)
#     sktime_dl.deeplearning.encoder._base.EncoderNetwork(sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork)
#         sktime_dl.deeplearning.encoder._classifier.EncoderClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.encoder._base.EncoderNetwork)
#         sktime_dl.deeplearning.encoder._regressor.EncoderRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.encoder._base.EncoderNetwork)
#     sktime_dl.deeplearning.fcn._base.FCNNetwork(sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork)
#         sktime_dl.deeplearning.fcn._classifier.FCNClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.fcn._base.FCNNetwork)
#         sktime_dl.deeplearning.fcn._regressor.FCNRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.fcn._base.FCNNetwork)
#     sktime_dl.deeplearning.inceptiontime._base.InceptionTimeNetwork(sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork)
#         sktime_dl.deeplearning.inceptiontime._classifier.InceptionTimeClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.inceptiontime._base.InceptionTimeNetwork)
#         sktime_dl.deeplearning.inceptiontime._regressor.InceptionTimeRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.inceptiontime._base.InceptionTimeNetwork)
#     sktime_dl.deeplearning.lstm._base.LSTMNetwork(sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork)
#         sktime_dl.deeplearning.lstm._regressor.LSTMRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.lstm._base.LSTMNetwork)
#     sktime_dl.deeplearning.mcdcnn._base.MCDCNNNetwork(sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork)
#         sktime_dl.deeplearning.mcdcnn._classifier.MCDCNNClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.mcdcnn._base.MCDCNNNetwork)
#         sktime_dl.deeplearning.mcdcnn._regressor.MCDCNNRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.mcdcnn._base.MCDCNNNetwork)
#     sktime_dl.deeplearning.mlp._base.MLPNetwork(sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork)
#         sktime_dl.deeplearning.mlp._classifier.MLPClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.mlp._base.MLPNetwork)
#         sktime_dl.deeplearning.mlp._regressor.MLPRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.mlp._base.MLPNetwork)
#     sktime_dl.deeplearning.resnet._base.ResNetNetwork(sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork)
#         sktime_dl.deeplearning.resnet._classifier.ResNetClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.resnet._base.ResNetNetwork)
#         sktime_dl.deeplearning.resnet._regressor.ResNetRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.resnet._base.ResNetNetwork)
#     sktime_dl.deeplearning.tlenet._base.TLENETNetwork(sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork)
#         sktime_dl.deeplearning.tlenet._classifier.TLENETClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.tlenet._base.TLENETNetwork)
#         sktime_dl.deeplearning.tlenet._regressor.TLENETRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.tlenet._base.TLENETNetwork)
#
#     class CNNClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.cnn._base.CNNNetwork)
#      |  CNNClassifier(nb_epochs=2000, batch_size=16, kernel_size=7, avg_pool_size=3, nb_conv_layers=2, filter_sizes=[6, 12], callbacks=None, random_state=0, verbose=False, model_name='cnn', model_save_directory=None)
#      |
#      |  Time Convolutional Neural Network (CNN).
#      |
#      |  Adapted from the implementation from Fawaz et. al
#      |
#      |  https://github.com/hfawaz/dl-4-tsc/blob/master/classifiers/cnn.py
#      |
#      |  Network originally defined in:
#      |  @article{zhao2017convolutional, title={Convolutional neural networks for
#      |  time series classification}, author={Zhao, Bendong and Lu, Huanzhang and
#      |  Chen, Shangfeng and Liu, Junliang and Wu, Dongya}, journal={Journal of
#      |  Systems Engineering and Electronics}, volume={28}, number={1}, pages={
#      |  162--169}, year={2017}, publisher={BIAI} }
#      |
#      |  :param nb_epochs: int, the number of epochs to train the model
#      |  :param batch_size: int, the number of samples per gradient update.
#      |  :param kernel_size: int, specifying the length of the 1D convolution
#      |   window
#      |  :param avg_pool_size: int, size of the average pooling windows
#      |  :param nb_conv_layers: int, the number of convolutional plus average
#      |   pooling layers
#      |  :param filter_sizes: int, array of shape = (nb_conv_layers)
#      |  :param callbacks: list of tf.keras.callbacks.Callback objects
#      |  :param random_state: int, or sklearn Random.state
#      |  :param verbose: boolean, whether to output extra information
#      |  :param model_name: string, the name of this model for printing and
#      |  file writing purposes
#      |  :param model_save_directory: string, if not None; location to save
#      |  the trained keras model in hdf5 format
#      |
#      |  Method resolution order:
#      |      CNNClassifier
#      |      sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier
#      |      sktime.classification.base.BaseClassifier
#      |      sktime.base._base.BaseEstimator
#      |      sklearn.base.BaseEstimator
#      |      sktime_dl.deeplearning.cnn._base.CNNNetwork
#      |      sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, nb_epochs=2000, batch_size=16, kernel_size=7, avg_pool_size=3, nb_conv_layers=2, filter_sizes=[6, 12], callbacks=None, random_state=0, verbose=False, model_name='cnn', model_save_directory=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  build_model(self, input_shape, nb_classes, **kwargs)
#      |      Construct a compiled, un-trained, keras model that is ready for
#      |      training
#      |      ----------
#      |      input_shape : tuple
#      |          The shape of the data fed into the input layer
#      |      nb_classes: int
#      |          The number of classes, which shall become the size of the output
#      |          layer
#      |      Returns
#      |      -------
#      |      output : a compiled Keras Model
#      |
#      |  fit(self, X, y, input_checks=True, validation_X=None, validation_y=None, **kwargs)
#      |      Fit the classifier on the training set (X, y)
#      |      ----------
#      |      X : a nested pd.Dataframe, or (if input_checks=False) array-like of
#      |      shape = (n_instances, series_length, n_dimensions)
#      |          The training input samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |      y : array-like, shape = [n_instances]
#      |          The training data class labels.
#      |      input_checks : boolean
#      |          whether to check the X and y parameters
#      |      validation_X : a nested pd.Dataframe, or array-like of shape =
#      |      (n_instances, series_length, n_dimensions)
#      |          The validation samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |          Unless strictly defined by the user via callbacks (such as
#      |          EarlyStopping), the presence or state of the validation
#      |          data does not alter training in any way. Predictions at each epoch
#      |          are stored in the model's fit history.
#      |      validation_y : array-like, shape = [n_instances]
#      |          The validation class labels.
#      |      Returns
#      |      -------
#      |      self : object
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier:
#      |
#      |  convert_y(self, y, label_encoder=None, onehot_encoder=None)
#      |
#      |  predict_proba(self, X, input_checks=True, **kwargs)
#      |      Find probability estimates for each class for all cases in X.
#      |      Parameters
#      |      ----------
#      |      X : a nested pd.Dataframe, or (if input_checks=False) array-like of
#      |      shape = (n_instances, series_length, n_dimensions)
#      |          The training input samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |      input_checks: boolean
#      |          whether to check the X parameter
#      |      Returns
#      |      -------
#      |      output : array of shape = [n_instances, n_classes] of probabilities
#      |
#      |  save_trained_model(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime.classification.base.BaseClassifier:
#      |
#      |  predict(self, X)
#      |      classify instances
#      |      ----
#      |      Parameters
#      |      ----
#      |      X : panda dataframe
#      |          instances of the dataset
#      |      ----
#      |      Returns
#      |      ----
#      |      predictions : 1d numpy array
#      |          array of predictions of each instance (class value)
#      |
#      |  score(self, X, y)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime.base._base.BaseEstimator:
#      |
#      |  check_is_fitted(self)
#      |      Check if the estimator has been fitted.
#      |
#      |      Raises
#      |      ------
#      |      NotFittedError
#      |          If the estimator has not been fitted yet.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from sktime.base._base.BaseEstimator:
#      |
#      |  is_fitted
#      |      Has `fit` been called?
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sklearn.base.BaseEstimator:
#      |
#      |  __getstate__(self)
#      |
#      |  __repr__(self, N_CHAR_MAX=700)
#      |      Return repr(self).
#      |
#      |  __setstate__(self, state)
#      |
#      |  get_params(self, deep=True)
#      |      Get parameters for this estimator.
#      |
#      |      Parameters
#      |      ----------
#      |      deep : bool, default=True
#      |          If True, will return the parameters for this estimator and
#      |          contained subobjects that are estimators.
#      |
#      |      Returns
#      |      -------
#      |      params : mapping of string to any
#      |          Parameter names mapped to their values.
#      |
#      |  set_params(self, **params)
#      |      Set the parameters of this estimator.
#      |
#      |      The method works on simple estimators as well as on nested objects
#      |      (such as pipelines). The latter have parameters of the form
#      |      ``<component>__<parameter>`` so that it's possible to update each
#      |      component of a nested object.
#      |
#      |      Parameters
#      |      ----------
#      |      **params : dict
#      |          Estimator parameters.
#      |
#      |      Returns
#      |      -------
#      |      self : object
#      |          Estimator instance.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from sklearn.base.BaseEstimator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime_dl.deeplearning.cnn._base.CNNNetwork:
#      |
#      |  build_network(self, input_shape, **kwargs)
#      |      Construct a network and return its input and output layers
#      |      ----------
#      |      input_shape : tuple
#      |          The shape of the data fed into the input layer
#      |      Returns
#      |      -------
#      |      input_layer : a keras layer
#      |      output_layer : a keras layer
#
#     class CNNRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.cnn._base.CNNNetwork)
#      |  CNNRegressor(nb_epochs=2000, batch_size=16, kernel_size=7, avg_pool_size=3, nb_conv_layers=2, filter_sizes=[6, 12], callbacks=None, random_state=0, verbose=False, model_name='cnn_regressor', model_save_directory=None)
#      |
#      |  Time Convolutional Neural Network (CNN).
#      |
#      |  Adapted from the implementation from Fawaz et. al
#      |
#      |  https://github.com/hfawaz/dl-4-tsc/blob/master/classifiers/cnn.py
#      |
#      |  Network originally defined in:
#      |
#      |  @article{zhao2017convolutional, title={Convolutional neural networks for
#      |  time series classification}, author={Zhao, Bendong and Lu, Huanzhang and
#      |  Chen, Shangfeng and Liu, Junliang and Wu, Dongya}, journal={Journal of
#      |  Systems Engineering and Electronics}, volume={28}, number={1}, pages={
#      |  162--169}, year={2017}, publisher={BIAI} }
#      |
#      |  :param nb_epochs: int, the number of epochs to train the model
#      |  :param batch_size: int, the number of samples per gradient update.
#      |  :param kernel_size: int, specifying the length of the 1D convolution
#      |   window
#      |  :param avg_pool_size: int, size of the average pooling windows
#      |  :param nb_conv_layers: int, the number of convolutional plus average
#      |   pooling layers
#      |  :param filter_sizes: int, array of shape = (nb_conv_layers)
#      |  :param callbacks: list of tf.keras.callbacks.Callback objects
#      |  :param random_state: int, seed to any needed random actions
#      |  :param verbose: boolean, whether to output extra information
#      |  :param model_name: string, the name of this model for printing and file
#      |   writing purposes
#      |  :param model_save_directory: string, if not None; location to save the
#      |   trained keras model in hdf5 format
#      |
#      |  Method resolution order:
#      |      CNNRegressor
#      |      sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor
#      |      sktime.regression.base.BaseRegressor
#      |      sktime.base._base.BaseEstimator
#      |      sklearn.base.BaseEstimator
#      |      sklearn.base.RegressorMixin
#      |      sktime_dl.deeplearning.cnn._base.CNNNetwork
#      |      sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, nb_epochs=2000, batch_size=16, kernel_size=7, avg_pool_size=3, nb_conv_layers=2, filter_sizes=[6, 12], callbacks=None, random_state=0, verbose=False, model_name='cnn_regressor', model_save_directory=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  build_model(self, input_shape, **kwargs)
#      |      Construct a compiled, un-trained, keras model that is ready for
#      |       training
#      |      ----------
#      |      input_shape : tuple
#      |          The shape of the data fed into the input layer
#      |      Returns
#      |      -------
#      |      output : a compiled Keras Model
#      |
#      |  fit(self, X, y, input_checks=True, validation_X=None, validation_y=None, **kwargs)
#      |      Fit the regressor on the training set (X, y)
#      |      ----------
#      |      X : a nested pd.Dataframe, or (if input_checks=False) array-like of
#      |      shape = (n_instances, series_length, n_dimensions)
#      |          The training input samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |      y : array-like, shape = [n_instances]
#      |          The training data class labels.
#      |      input_checks : boolean
#      |          whether to check the X and y parameters
#      |      validation_X : a nested pd.Dataframe, or array-like of shape =
#      |      (n_instances, series_length, n_dimensions)
#      |          The validation samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |          Unless strictly defined by the user via callbacks (such as
#      |          EarlyStopping), the presence or state of the validation
#      |          data does not alter training in any way. Predictions at each epoch
#      |          are stored in the model's fit history.
#      |      validation_y : array-like, shape = [n_instances]
#      |          The validation class labels.
#      |      Returns
#      |      -------
#      |      self : object
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor:
#      |
#      |  predict(self, X, input_checks=True, **kwargs)
#      |      Find regression estimate for all cases in X.
#      |      Parameters
#      |      ----------
#      |      X : a nested pd.Dataframe, or (if input_checks=False) array-like of
#      |      shape = (n_instances, series_length, n_dimensions)
#      |          The training input samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |      input_checks: boolean
#      |          whether to check the X parameter
#      |      Returns
#      |      -------
#      |      predictions : 1d numpy array
#      |          array of predictions of each instance
#      |
#      |  save_trained_model(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime.regression.base.BaseRegressor:
#      |
#      |  score(self, X, y)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime.base._base.BaseEstimator:
#      |
#      |  check_is_fitted(self)
#      |      Check if the estimator has been fitted.
#      |
#      |      Raises
#      |      ------
#      |      NotFittedError
#      |          If the estimator has not been fitted yet.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from sktime.base._base.BaseEstimator:
#      |
#      |  is_fitted
#      |      Has `fit` been called?
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sklearn.base.BaseEstimator:
#      |
#      |  __getstate__(self)
#      |
#      |  __repr__(self, N_CHAR_MAX=700)
#      |      Return repr(self).
#      |
#      |  __setstate__(self, state)
#      |
#      |  get_params(self, deep=True)
#      |      Get parameters for this estimator.
#      |
#      |      Parameters
#      |      ----------
#      |      deep : bool, default=True
#      |          If True, will return the parameters for this estimator and
#      |          contained subobjects that are estimators.
#      |
#      |      Returns
#      |      -------
#      |      params : mapping of string to any
#      |          Parameter names mapped to their values.
#      |
#      |  set_params(self, **params)
#      |      Set the parameters of this estimator.
#      |
#      |      The method works on simple estimators as well as on nested objects
#      |      (such as pipelines). The latter have parameters of the form
#      |      ``<component>__<parameter>`` so that it's possible to update each
#      |      component of a nested object.
#      |
#      |      Parameters
#      |      ----------
#      |      **params : dict
#      |          Estimator parameters.
#      |
#      |      Returns
#      |      -------
#      |      self : object
#      |          Estimator instance.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from sklearn.base.BaseEstimator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime_dl.deeplearning.cnn._base.CNNNetwork:
#      |
#      |  build_network(self, input_shape, **kwargs)
#      |      Construct a network and return its input and output layers
#      |      ----------
#      |      input_shape : tuple
#      |          The shape of the data fed into the input layer
#      |      Returns
#      |      -------
#      |      input_layer : a keras layer
#      |      output_layer : a keras layer
#
#     class EncoderClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.encoder._base.EncoderNetwork)
#      |  EncoderClassifier(nb_epochs=100, batch_size=12, callbacks=None, random_state=0, verbose=False, model_name='encoder', model_save_directory=None)
#      |
#      |  Encoder
#      |
#      |  Adapted from the implementation from Fawaz et. al
#      |
#      |  https://github.com/hfawaz/dl-4-tsc/blob/master/classifiers/encoder.py
#      |
#      |  Network originally defined in:
#      |
#      |  @article{serra2018towards,
#      |     title={Towards a universal neural network encoder for time series},
#      |     author={Serrà, J and Pascual, S and Karatzoglou, A},
#      |     journal={Artif Intell Res Dev Curr Chall New Trends Appl},
#      |     volume={308},
#      |     pages={120},
#      |     year={2018}
#      |  }
#      |
#      |  :param nb_epochs: int, the number of epochs to train the model
#      |  :param batch_size: int, specifying the length of the 1D convolution
#      |   window
#      |  :param callbacks: list of tf.keras.callbacks.Callback objects
#      |  :param random_state: int, seed to any needed random actions
#      |  :param verbose: boolean, whether to output extra information
#      |  :param model_name: string, the name of this model for printing and
#      |   file writing purposes
#      |  :param model_save_directory: string, if not None; location to save
#      |   the trained keras model in hdf5 format
#      |
#      |  Method resolution order:
#      |      EncoderClassifier
#      |      sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier
#      |      sktime.classification.base.BaseClassifier
#      |      sktime.base._base.BaseEstimator
#      |      sklearn.base.BaseEstimator
#      |      sktime_dl.deeplearning.encoder._base.EncoderNetwork
#      |      sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, nb_epochs=100, batch_size=12, callbacks=None, random_state=0, verbose=False, model_name='encoder', model_save_directory=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  build_model(self, input_shape, nb_classes, **kwargs)
#      |      Construct a compiled, un-trained, keras model that is ready for
#      |       training
#      |      ----------
#      |      input_shape : tuple
#      |          The shape of the data fed into the input layer
#      |      nb_classes: int
#      |          The number of classes, which shall become the size of the output
#      |           layer
#      |      Returns
#      |      -------
#      |      output : a compiled Keras Model
#      |
#      |  fit(self, X, y, input_checks=True, validation_X=None, validation_y=None, **kwargs)
#      |      Fit the classifier on the training set (X, y)
#      |      ----------
#      |      X : a nested pd.Dataframe, or (if input_checks=False) array-like of
#      |      shape = (n_instances, series_length, n_dimensions)
#      |          The training input samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |      y : array-like, shape = [n_instances]
#      |          The training data class labels.
#      |      input_checks : boolean
#      |          whether to check the X and y parameters
#      |      validation_X : a nested pd.Dataframe, or array-like of shape =
#      |      (n_instances, series_length, n_dimensions)
#      |          The validation samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |          Unless strictly defined by the user via callbacks (such as
#      |          EarlyStopping), the presence or state of the validation
#      |          data does not alter training in any way. Predictions at each epoch
#      |          are stored in the model's fit history.
#      |      validation_y : array-like, shape = [n_instances]
#      |          The validation class labels.
#      |      Returns
#      |      -------
#      |      self : object
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier:
#      |
#      |  convert_y(self, y, label_encoder=None, onehot_encoder=None)
#      |
#      |  predict_proba(self, X, input_checks=True, **kwargs)
#      |      Find probability estimates for each class for all cases in X.
#      |      Parameters
#      |      ----------
#      |      X : a nested pd.Dataframe, or (if input_checks=False) array-like of
#      |      shape = (n_instances, series_length, n_dimensions)
#      |          The training input samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |      input_checks: boolean
#      |          whether to check the X parameter
#      |      Returns
#      |      -------
#      |      output : array of shape = [n_instances, n_classes] of probabilities
#      |
#      |  save_trained_model(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime.classification.base.BaseClassifier:
#      |
#      |  predict(self, X)
#      |      classify instances
#      |      ----
#      |      Parameters
#      |      ----
#      |      X : panda dataframe
#      |          instances of the dataset
#      |      ----
#      |      Returns
#      |      ----
#      |      predictions : 1d numpy array
#      |          array of predictions of each instance (class value)
#      |
#      |  score(self, X, y)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime.base._base.BaseEstimator:
#      |
#      |  check_is_fitted(self)
#      |      Check if the estimator has been fitted.
#      |
#      |      Raises
#      |      ------
#      |      NotFittedError
#      |          If the estimator has not been fitted yet.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from sktime.base._base.BaseEstimator:
#      |
#      |  is_fitted
#      |      Has `fit` been called?
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sklearn.base.BaseEstimator:
#      |
#      |  __getstate__(self)
#      |
#      |  __repr__(self, N_CHAR_MAX=700)
#      |      Return repr(self).
#      |
#      |  __setstate__(self, state)
#      |
#      |  get_params(self, deep=True)
#      |      Get parameters for this estimator.
#      |
#      |      Parameters
#      |      ----------
#      |      deep : bool, default=True
#      |          If True, will return the parameters for this estimator and
#      |          contained subobjects that are estimators.
#      |
#      |      Returns
#      |      -------
#      |      params : mapping of string to any
#      |          Parameter names mapped to their values.
#      |
#      |  set_params(self, **params)
#      |      Set the parameters of this estimator.
#      |
#      |      The method works on simple estimators as well as on nested objects
#      |      (such as pipelines). The latter have parameters of the form
#      |      ``<component>__<parameter>`` so that it's possible to update each
#      |      component of a nested object.
#      |
#      |      Parameters
#      |      ----------
#      |      **params : dict
#      |          Estimator parameters.
#      |
#      |      Returns
#      |      -------
#      |      self : object
#      |          Estimator instance.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from sklearn.base.BaseEstimator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime_dl.deeplearning.encoder._base.EncoderNetwork:
#      |
#      |  build_network(self, input_shape, **kwargs)
#      |      Construct a network and return its input and output layers
#      |      ----------
#      |      input_shape : tuple
#      |          The shape of the data fed into the input layer
#      |      Returns
#      |      -------
#      |      input_layer : a keras layer
#      |      output_layer : a keras layer
#
#     class EncoderRegressor(sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor, sktime_dl.deeplearning.encoder._base.EncoderNetwork)
#      |  EncoderRegressor(nb_epochs=2000, batch_size=16, callbacks=None, random_state=0, verbose=False, model_name='encoder_regressor', model_save_directory=None)
#      |
#      |  Encoder
#      |
#      |  Adapted from the implementation from Fawaz et. al
#      |
#      |  https://github.com/hfawaz/dl-4-tsc/blob/master/classifiers/encoder.py
#      |
#      |  Network originally defined in:
#      |
#      |  @article{serra2018towards,
#      |     title={Towards a universal neural network encoder for time series},
#      |     author={Serrà, J and Pascual, S and Karatzoglou, A},
#      |     journal={Artif Intell Res Dev Curr Chall New Trends Appl},
#      |     volume={308},
#      |     pages={120},
#      |     year={2018}
#      |  }
#      |  :param nb_epochs: int, the number of epochs to train the model
#      |  :param batch_size: int, specifying the length of the 1D convolution
#      |   window
#      |  :param callbacks: list of tf.keras.callbacks.Callback objects
#      |  :param random_state: int, seed to any needed random actions
#      |  :param verbose: boolean, whether to output extra information
#      |  :param model_name: string, the name of this model for printing and
#      |  file writing purposes
#      |  :param model_save_directory: string, if not None; location to save the
#      |   trained keras model in hdf5 format
#      |
#      |  Method resolution order:
#      |      EncoderRegressor
#      |      sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor
#      |      sktime.regression.base.BaseRegressor
#      |      sktime.base._base.BaseEstimator
#      |      sklearn.base.BaseEstimator
#      |      sklearn.base.RegressorMixin
#      |      sktime_dl.deeplearning.encoder._base.EncoderNetwork
#      |      sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, nb_epochs=2000, batch_size=16, callbacks=None, random_state=0, verbose=False, model_name='encoder_regressor', model_save_directory=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  build_model(self, input_shape, **kwargs)
#      |      Construct a compiled, un-trained, keras model that is ready for
#      |      training
#      |      ----------
#      |      input_shape : tuple
#      |          The shape of the data fed into the input layer
#      |      Returns
#      |      -------
#      |      output : a compiled Keras Model
#      |
#      |  fit(self, X, y, input_checks=True, validation_X=None, validation_y=None, **kwargs)
#      |      Fit the regressor on the training set (X, y)
#      |      ----------
#      |      X : a nested pd.Dataframe, or (if input_checks=False) array-like of
#      |      shape = (n_instances, series_length, n_dimensions)
#      |          The training input samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |      y : array-like, shape = [n_instances]
#      |          The training data class labels.
#      |      input_checks : boolean
#      |          whether to check the X and y parameters
#      |      validation_X : a nested pd.Dataframe, or array-like of shape =
#      |      (n_instances, series_length, n_dimensions)
#      |          The validation samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |          Unless strictly defined by the user via callbacks (such as
#      |          EarlyStopping), the presence or state of the validation
#      |          data does not alter training in any way. Predictions at each epoch
#      |          are stored in the model's fit history.
#      |      validation_y : array-like, shape = [n_instances]
#      |          The validation class labels.
#      |      Returns
#      |      -------
#      |      self : object
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor:
#      |
#      |  predict(self, X, input_checks=True, **kwargs)
#      |      Find regression estimate for all cases in X.
#      |      Parameters
#      |      ----------
#      |      X : a nested pd.Dataframe, or (if input_checks=False) array-like of
#      |      shape = (n_instances, series_length, n_dimensions)
#      |          The training input samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |      input_checks: boolean
#      |          whether to check the X parameter
#      |      Returns
#      |      -------
#      |      predictions : 1d numpy array
#      |          array of predictions of each instance
#      |
#      |  save_trained_model(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime.regression.base.BaseRegressor:
#      |
#      |  score(self, X, y)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime.base._base.BaseEstimator:
#      |
#      |  check_is_fitted(self)
#      |      Check if the estimator has been fitted.
#      |
#      |      Raises
#      |      ------
#      |      NotFittedError
#      |          If the estimator has not been fitted yet.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from sktime.base._base.BaseEstimator:
#      |
#      |  is_fitted
#      |      Has `fit` been called?
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sklearn.base.BaseEstimator:
#      |
#      |  __getstate__(self)
#      |
#      |  __repr__(self, N_CHAR_MAX=700)
#      |      Return repr(self).
#      |
#      |  __setstate__(self, state)
#      |
#      |  get_params(self, deep=True)
#      |      Get parameters for this estimator.
#      |
#      |      Parameters
#      |      ----------
#      |      deep : bool, default=True
#      |          If True, will return the parameters for this estimator and
#      |          contained subobjects that are estimators.
#      |
#      |      Returns
#      |      -------
#      |      params : mapping of string to any
#      |          Parameter names mapped to their values.
#      |
#      |  set_params(self, **params)
#      |      Set the parameters of this estimator.
#      |
#      |      The method works on simple estimators as well as on nested objects
#      |      (such as pipelines). The latter have parameters of the form
#      |      ``<component>__<parameter>`` so that it's possible to update each
#      |      component of a nested object.
#      |
#      |      Parameters
#      |      ----------
#      |      **params : dict
#      |          Estimator parameters.
#      |
#      |      Returns
#      |      -------
#      |      self : object
#      |          Estimator instance.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from sklearn.base.BaseEstimator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime_dl.deeplearning.encoder._base.EncoderNetwork:
#      |
#      |  build_network(self, input_shape, **kwargs)
#      |      Construct a network and return its input and output layers
#      |      ----------
#      |      input_shape : tuple
#      |          The shape of the data fed into the input layer
#      |      Returns
#      |      -------
#      |      input_layer : a keras layer
#      |      output_layer : a keras layer
#
#     class FCNClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier, sktime_dl.deeplearning.fcn._base.FCNNetwork)
#      |  FCNClassifier(nb_epochs=2000, batch_size=16, callbacks=None, random_state=0, verbose=False, model_name='fcn', model_save_directory=None)
#      |
#      |  Fully convolutional neural network (FCN).
#      |
#      |  Adapted from the implementation from Fawaz et. al`
#      |
#      |  https://github.com/hfawaz/dl-4-tsc/blob/master/classifiers/fcn.py
#      |
#      |  Network originally defined in:
#      |
#      |  @inproceedings{wang2017time, title={Time series classification from
#      |  scratch with deep neural networks: A strong baseline}, author={Wang,
#      |  Zhiguang and Yan, Weizhong and Oates, Tim}, booktitle={2017
#      |  International joint conference on neural networks (IJCNN)}, pages={
#      |  1578--1585}, year={2017}, organization={IEEE} }
#      |
#      |  :param nb_epochs: int, the number of epochs to train the model
#      |  :param batch_size: int, specifying the length of the 1D convolution
#      |   window
#      |  :param callbacks: list of tf.keras.callbacks.Callback objects
#      |  :param random_state: int, seed to any needed random actions
#      |  :param verbose: boolean, whether to output extra information
#      |  :param model_name: string, the name of this model for printing and
#      |   file writing purposes
#      |  :param model_save_directory: string, if not None; location to save
#      |   the trained keras model in hdf5 format
#      |
#      |  Method resolution order:
#      |      FCNClassifier
#      |      sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier
#      |      sktime.classification.base.BaseClassifier
#      |      sktime.base._base.BaseEstimator
#      |      sklearn.base.BaseEstimator
#      |      sktime_dl.deeplearning.fcn._base.FCNNetwork
#      |      sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, nb_epochs=2000, batch_size=16, callbacks=None, random_state=0, verbose=False, model_name='fcn', model_save_directory=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  build_model(self, input_shape, nb_classes, **kwargs)
#      |      Construct a compiled, un-trained, keras model that is ready for
#      |       training
#      |      ----------
#      |      input_shape : tuple
#      |          The shape of the data fed into the input layer
#      |      nb_classes: int
#      |          The number of classes, which shall become the size of the output
#      |           layer
#      |      Returns
#      |      -------
#      |      output : a compiled Keras Model
#      |
#      |  fit(self, X, y, input_checks=True, validation_X=None, validation_y=None, **kwargs)
#      |      Fit the classifier on the training set (X, y)
#      |      ----------
#      |      X : a nested pd.Dataframe, or (if input_checks=False) array-like of
#      |      shape = (n_instances, series_length, n_dimensions)
#      |          The training input samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |      y : array-like, shape = [n_instances]
#      |          The training data class labels.
#      |      input_checks : boolean
#      |          whether to check the X and y parameters
#      |      validation_X : a nested pd.Dataframe, or array-like of shape =
#      |      (n_instances, series_length, n_dimensions)
#      |          The validation samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |          Unless strictly defined by the user via callbacks (such as
#      |          EarlyStopping), the presence or state of the validation
#      |          data does not alter training in any way. Predictions at each epoch
#      |          are stored in the model's fit history.
#      |      validation_y : array-like, shape = [n_instances]
#      |          The validation class labels.
#      |      Returns
#      |      -------
#      |      self : object
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier:
#      |
#      |  convert_y(self, y, label_encoder=None, onehot_encoder=None)
#      |
#      |  predict_proba(self, X, input_checks=True, **kwargs)
#      |      Find probability estimates for each class for all cases in X.
#      |      Parameters
#      |      ----------
#      |      X : a nested pd.Dataframe, or (if input_checks=False) array-like of
#      |      shape = (n_instances, series_length, n_dimensions)
#      |          The training input samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |      input_checks: boolean
#      |          whether to check the X parameter
#      |      Returns
#      |      -------
#      |      output : array of shape = [n_instances, n_classes] of probabilities
#      |
#      |  save_trained_model(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime.classification.base.BaseClassifier:
#      |
#      |  predict(self, X)
#      |      classify instances
#      |      ----
#      |      Parameters
#      |      ----
#      |      X : panda dataframe
#      |          instances of the dataset
#      |      ----
#      |      Returns
#      |      ----
#      |      predictions : 1d numpy array
#      |          array of predictions of each instance (class value)
#      |
#      |  score(self, X, y)
#      |
# ...
#      |  Arthur and Malinowski, Simon and Tavenard, Romain}, booktitle={ECML/PKDD
#      |  workshop on advanced analytics and learning on temporal data},
#      |  year={2016} }
#      |
#      |  Method resolution order:
#      |      TLENETRegressor
#      |      sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor
#      |      sktime.regression.base.BaseRegressor
#      |      sktime.base._base.BaseEstimator
#      |      sklearn.base.BaseEstimator
#      |      sklearn.base.RegressorMixin
#      |      sktime_dl.deeplearning.tlenet._base.TLENETNetwork
#      |      sktime_dl.deeplearning.base.estimators._network.BaseDeepNetwork
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, nb_epochs=1000, batch_size=256, warping_ratios=[0.5, 1, 2], slice_ratio=0.1, callbacks=None, verbose=False, random_state=0, model_name='tlenet_regressor', model_save_directory=None)
#      |      :param nb_epochs: int, the number of epochs to train the model
#      |      :param batch_size: int, specifying the length of the 1D convolution
#      |       window
#      |      :param warping_ratios: list of floats, warping ratio for each window
#      |      :param slice_ratio: float, ratio of the time series used to create a
#      |       slice
#      |      :param callbacks: list of tf.keras.callbacks.Callback objects
#      |      :param random_state: int, seed to any needed random actions
#      |      :param verbose: boolean, whether to output extra information
#      |      :param model_name: string, the name of this model for printing and
#      |       file writing purposes
#      |      :param model_save_directory: string, if not None; location to save
#      |       the trained keras model in hdf5 format
#      |
#      |  build_model(self, input_shape, **kwargs)
#      |      Construct a compiled, un-trained, keras model that is ready for
#      |       training
#      |      ----------
#      |      input_shape : tuple
#      |          The shape of the data fed into the input layer
#      |      Returns
#      |      -------
#      |      output : a compiled Keras Model
#      |
#      |  fit(self, X, y, input_checks=True, validation_X=None, validation_y=None, **kwargs)
#      |      Fit the regressor on the training set (X, y)
#      |      ----------
#      |      X : a nested pd.Dataframe, or (if input_checks=False) array-like of
#      |      shape = (n_instances, series_length, n_dimensions)
#      |          The training input samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |      y : array-like, shape = [n_instances]
#      |          The training data class labels.
#      |      input_checks : boolean
#      |          whether to check the X and y parameters
#      |      validation_X : a nested pd.Dataframe, or array-like of shape =
#      |      (n_instances, series_length, n_dimensions)
#      |          The validation samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |          Unless strictly defined by the user via callbacks (such as
#      |          EarlyStopping), the presence or state of the validation
#      |          data does not alter training in any way. Predictions at each epoch
#      |          are stored in the model's fit history.
#      |      validation_y : array-like, shape = [n_instances]
#      |          The validation class labels.
#      |      Returns
#      |      -------
#      |      self : object
#      |
#      |  predict(self, X, input_checks=True, **kwargs)
#      |      Find regression estimate for all cases in X.
#      |      Parameters
#      |      ----------
#      |      X : a nested pd.Dataframe, or (if input_checks=False) array-like of
#      |      shape = (n_instances, series_length, n_dimensions)
#      |          The training input samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |      input_checks: boolean
#      |          whether to check the X parameter
#      |      Returns
#      |      -------
#      |      predictions : 1d numpy array
#      |          array of predictions of each instance
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime_dl.deeplearning.base.estimators._regressor.BaseDeepRegressor:
#      |
#      |  save_trained_model(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime.regression.base.BaseRegressor:
#      |
#      |  score(self, X, y)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime.base._base.BaseEstimator:
#      |
#      |  check_is_fitted(self)
#      |      Check if the estimator has been fitted.
#      |
#      |      Raises
#      |      ------
#      |      NotFittedError
#      |          If the estimator has not been fitted yet.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from sktime.base._base.BaseEstimator:
#      |
#      |  is_fitted
#      |      Has `fit` been called?
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sklearn.base.BaseEstimator:
#      |
#      |  __getstate__(self)
#      |
#      |  __repr__(self, N_CHAR_MAX=700)
#      |      Return repr(self).
#      |
#      |  __setstate__(self, state)
#      |
#      |  get_params(self, deep=True)
#      |      Get parameters for this estimator.
#      |
#      |      Parameters
#      |      ----------
#      |      deep : bool, default=True
#      |          If True, will return the parameters for this estimator and
#      |          contained subobjects that are estimators.
#      |
#      |      Returns
#      |      -------
#      |      params : mapping of string to any
#      |          Parameter names mapped to their values.
#      |
#      |  set_params(self, **params)
#      |      Set the parameters of this estimator.
#      |
#      |      The method works on simple estimators as well as on nested objects
#      |      (such as pipelines). The latter have parameters of the form
#      |      ``<component>__<parameter>`` so that it's possible to update each
#      |      component of a nested object.
#      |
#      |      Parameters
#      |      ----------
#      |      **params : dict
#      |          Estimator parameters.
#      |
#      |      Returns
#      |      -------
#      |      self : object
#      |          Estimator instance.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from sklearn.base.BaseEstimator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime_dl.deeplearning.tlenet._base.TLENETNetwork:
#      |
#      |  adjust_parameters(self, X)
#      |      Adjust warping and slicing for overly long or short data.
#      |
#      |  build_network(self, input_shape, **kwargs)
#      |      Construct a network and return its input and output layers
#      |      ----------
#      |      input_shape : tuple
#      |          The shape of the data fed into the input layer
#      |      Returns
#      |      -------
#      |      input_layer : a keras layer
#      |      output_layer : a keras layer
#      |
#      |  pre_processing(self, X, y=None)
#      |
#      |  slice_data(self, X, y=None, length_sliced=1)
#      |      Perform window slicing (WS) to provide additional data.
#      |
#      |      "At training, each slice extracted from a time series of class y is
#      |      assigned the same class and a classifier is learned using the slices.
#      |      The size of the slice is a parameter of this method. At test time, each
#      |      slice from a test time series is classified using the learned
#      |      classifier and a majority vote is performed to decide a predicted
#      |      label." Le Guennec et al. (2016)
#      |
#      |  window_warping(self, data_x, warping_ratio)
#      |      Warp a slice of a time series by speeding it up or down.
#      |
#      |      "This method generates input time series of different lengths. To deal
#      |      with this issue, we [then] perform window slicing on transformed
#      |      timeseries for all to have equal length" Le Guennec et al. (2016)
#
#     class TWIESNClassifier(sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier)
#      |  TWIESNClassifier(rho_s=[0.55, 0.9, 2.0, 5.0], alpha=0.1, random_state=0, verbose=False, model_name='twiesn', model_save_directory=None)
#      |
#      |  Time Warping Invariant Echo State Network (TWIESN).
#      |
#      |  Adapted from the implementation from Fawaz et. al
#      |
#      |  https://github.com/hfawaz/dl-4-tsc/blob/master/classifiers/twiesn.py
#      |
#      |  Network originally defined in:
#      |
#      |  @inproceedings{tanisaro2016time, title={Time series classification using
#      |  time warping invariant echo state networks}, author={Tanisaro, Pattreeya
#      |  and Heidemann, Gunther}, booktitle={2016 15th IEEE International
#      |  Conference on Machine Learning and Applications (ICMLA)}, pages={
#      |  831--836}, year={2016}, organization={IEEE} }
#      |
#      |  Method resolution order:
#      |      TWIESNClassifier
#      |      sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier
#      |      sktime.classification.base.BaseClassifier
#      |      sktime.base._base.BaseEstimator
#      |      sklearn.base.BaseEstimator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, rho_s=[0.55, 0.9, 2.0, 5.0], alpha=0.1, random_state=0, verbose=False, model_name='twiesn', model_save_directory=None)
#      |      :param rho_s: array of shape
#      |      :param alpha: float, the leakage rate
#      |      :param random_state: int, seed to any needed random actions
#      |      :param verbose: boolean, whether to output extra information
#      |      :param model_name: string, the name of this model for printing and
#      |       file writing purposes
#      |      :param model_save_directory: string, if not None; location to save
#      |       the trained keras model in hdf5 format
#      |
#      |  compute_state_matrix(self, x_in)
#      |
#      |  evaluate_paramset(self, X, y, val_X, val_y, rho, config)
#      |
#      |  fit(self, X, y, input_checks=True, **kwargs)
#      |      Fit the classifier on the training set (X, y)
#      |      ----------
#      |      X : a nested pd.Dataframe, or (if input_checks=False) array-like of
#      |      shape = (n_instances, series_length, n_dimensions)
#      |          The training input samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |      y : array-like, shape = [n_instances]
#      |          The training data class labels.
#      |      input_checks : boolean
#      |          whether to check the X and y parameters
#      |      Returns
#      |      -------
#      |      self : object
#      |
#      |  init_matrices(self)
#      |
#      |  predict_proba(self, X, input_checks=True, **kwargs)
#      |      Find probability estimates for each class for all cases in X.
#      |      Parameters
#      |      ----------
#      |      X : a nested pd.Dataframe, or (if input_checks=False) array-like of
#      |      shape = (n_instances, series_length, n_dimensions)
#      |          The training input samples. If a 2D array-like is passed,
#      |          n_dimensions is assumed to be 1.
#      |      input_checks: boolean
#      |          whether to check the X parameter
#      |      Returns
#      |      -------
#      |      output : array of shape = [n_instances, n_classes] of probabilities
#      |
#      |  reshape_prediction(self, y_pred, num_instances, length_series)
#      |
#      |  set_hyperparameters(self)
#      |
#      |  transform_to_feature_space(self, X)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime_dl.deeplearning.base.estimators._classifier.BaseDeepClassifier:
#      |
#      |  build_model(self, input_shape, nb_classes, **kwargs)
#      |      Construct a compiled, un-trained, keras model that is ready for
#      |      training
#      |
#      |      Parameters
#      |      ----------
#      |      input_shape : tuple
#      |          The shape of the data fed into the input layer
#      |      nb_classes: int
#      |          The number of classes, which shall become the size of the output
#      |          layer
#      |      Returns
#      |      -------
#      |      output : a compiled Keras Model
#      |
#      |  convert_y(self, y, label_encoder=None, onehot_encoder=None)
#      |
#      |  save_trained_model(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime.classification.base.BaseClassifier:
#      |
#      |  predict(self, X)
#      |      classify instances
#      |      ----
#      |      Parameters
#      |      ----
#      |      X : panda dataframe
#      |          instances of the dataset
#      |      ----
#      |      Returns
#      |      ----
#      |      predictions : 1d numpy array
#      |          array of predictions of each instance (class value)
#      |
#      |  score(self, X, y)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sktime.base._base.BaseEstimator:
#      |
#      |  check_is_fitted(self)
#      |      Check if the estimator has been fitted.
#      |
#      |      Raises
#      |      ------
#      |      NotFittedError
#      |          If the estimator has not been fitted yet.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from sktime.base._base.BaseEstimator:
#      |
#      |  is_fitted
#      |      Has `fit` been called?
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from sklearn.base.BaseEstimator:
#      |
#      |  __getstate__(self)
#      |
#      |  __repr__(self, N_CHAR_MAX=700)
#      |      Return repr(self).
#      |
#      |  __setstate__(self, state)
#      |
#      |  get_params(self, deep=True)
#      |      Get parameters for this estimator.
#      |
#      |      Parameters
#      |      ----------
#      |      deep : bool, default=True
#      |          If True, will return the parameters for this estimator and
#      |          contained subobjects that are estimators.
#      |
#      |      Returns
#      |      -------
#      |      params : mapping of string to any
#      |          Parameter names mapped to their values.
#      |
#      |  set_params(self, **params)
#      |      Set the parameters of this estimator.
#      |
#      |      The method works on simple estimators as well as on nested objects
#      |      (such as pipelines). The latter have parameters of the form
#      |      ``<component>__<parameter>`` so that it's possible to update each
#      |      component of a nested object.
#      |
#      |      Parameters
#      |      ----------
#      |      **params : dict
#      |          Estimator parameters.
#      |
#      |      Returns
#      |      -------
#      |      self : object
#      |          Estimator instance.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from sklearn.base.BaseEstimator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# DATA
#     __all__ = ['CNNClassifier', 'CNNRegressor', 'EncoderClassifier', 'Enco...
#
# FILE
#     /home/andrine/Desktop/sktime-dl/sktime_dl/deeplearning/__init__.py
