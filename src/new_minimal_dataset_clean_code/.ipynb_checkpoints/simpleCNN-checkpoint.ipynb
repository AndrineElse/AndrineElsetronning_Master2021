# %% [markdown]
# Sources for plotting the extracted features:
#
#
# https://medium.com/@Rehan_Sayyad/how-to-use-convolutional-neural-networks-for-time-series-classification-80575131a474
#
# https://machinelearningmastery.com/cnn-models-for-human-activity-recognition-time-series-classification/

# %%
import sys
import os
import pandas as pd
import numpy as np
from sklearn.utils import shuffle
module_path = os.path.abspath(os.path.join('../..'))

sys.path.insert(1, module_path + '/src')
import audio_time_series_classification as preproject
import utility

sys.path.insert(1, module_path + '/src/models/')
import helper

from sktime.utils.data_io import load_from_tsfile_to_dataframe
from sktime.utils.data_processing import from_nested_to_2d_array
import matplotlib.pyplot as plt
from sklearn import preprocessing

from keras.utils import np_utils
import keras
from keras.models import Model
from keras.models import Sequential
from keras.layers import Conv1D, ZeroPadding1D, MaxPooling1D, BatchNormalization, Activation, Dropout, Flatten, Dense


figure_path = module_path + '/figures/small_segment_dataset_plots/'

# %%
X_train, y_train_ = load_from_tsfile_to_dataframe(module_path + '/data/ts_files/minimal_dataset_2class_TRAIN.ts')
X_test, y_test_ = load_from_tsfile_to_dataframe(module_path + '/data/ts_files/minimal_dataset_2class_TEST.ts')
X_val, y_val_ = load_from_tsfile_to_dataframe(module_path + '/data/ts_files/minimal_dataset_2class_VAL.ts')

X_train, y_train_= shuffle(X_train, y_train_, random_state = 42)

X_train, X_test, X_val = from_nested_to_2d_array(X_train), from_nested_to_2d_array(X_test), from_nested_to_2d_array(X_val)

cols = np.arange(len(X_test.columns))
X_train.columns, X_test.columns, X_val.columns = cols, cols, cols

y_train_, y_test_, y_val_ = pd.Series(y_train_), pd.Series(y_test_), pd.Series(y_val_)
X_train = X_train.to_numpy()
X_test = X_test.to_numpy()
X_val = X_val.to_numpy()

X_train, y_train_= shuffle(X_train, y_train_, random_state = 42)
X_val, y_val_= shuffle(X_val, y_val_, random_state = 42)

X_train = X_train.reshape(X_train.shape[0],X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1], 1)

le = preprocessing.LabelEncoder()

le.fit(y_train_)
num_classes = len(le.classes_)
y_train = le.transform(y_train_)
y_test = le.transform(y_test_)
y_val = le.transform(y_val_)

y_train = np_utils.to_categorical(y_train, num_classes = num_classes)
y_test = np_utils.to_categorical(y_test, num_classes = num_classes)
y_val = np_utils.to_categorical(y_val, num_classes = num_classes)

# %% [markdown]
# # Models

# %%
batch_size = 100
epochs = 50
input_shape=(X_train.shape[1], 1)

model = Sequential()

model.add(Conv1D(filters=50, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(BatchNormalization()) 
model.add(MaxPooling1D(pool_size=5))
model.add(Flatten())
model.add(Dense(1000, activation='relu'))
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 3998, 50)          200
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 3998, 50)          200
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 799, 50)           0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 39950)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1000)              39951000
# _________________________________________________________________
# dense_7 (Dense)              (None, 500)               500500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 1002
# =================================================================
# Total params: 40,452,902
# Trainable params: 40,452,802
# Non-trainable params: 100
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs = epochs,
          batch_size = batch_size,
          verbose = 1,
         validation_data = (X_val, y_val))
# Out:
# Epoch 1/100
# 44/44 [==============================] - 9s 197ms/step - loss: 0.7604 - val_loss: 0.7126
# Epoch 2/100
# 44/44 [==============================] - 8s 192ms/step - loss: 0.6641 - val_loss: 0.7350
# Epoch 3/100
# 44/44 [==============================] - 8s 190ms/step - loss: 0.4230 - val_loss: 0.8172
# Epoch 4/100
# 44/44 [==============================] - 8s 191ms/step - loss: 0.2398 - val_loss: 1.1485
# Epoch 5/100
# 44/44 [==============================] - 8s 193ms/step - loss: 0.0941 - val_loss: 0.8390
# Epoch 6/100
# 44/44 [==============================] - 8s 192ms/step - loss: 0.0741 - val_loss: 2.3506
# Epoch 7/100
# 44/44 [==============================] - 8s 189ms/step - loss: 0.0972 - val_loss: 1.5262
# Epoch 8/100
# 44/44 [==============================] - 8s 191ms/step - loss: 0.2402 - val_loss: 2.0024
# Epoch 9/100
# 44/44 [==============================] - 8s 194ms/step - loss: 0.0507 - val_loss: 1.0897
# Epoch 10/100
# 44/44 [==============================] - 8s 191ms/step - loss: 0.0698 - val_loss: 3.4681
# Epoch 11/100
# 44/44 [==============================] - 8s 192ms/step - loss: 0.0177 - val_loss: 3.2721
# Epoch 12/100
# 44/44 [==============================] - 9s 194ms/step - loss: 0.0777 - val_loss: 1.6471
# Epoch 13/100
# 44/44 [==============================] - 9s 195ms/step - loss: 0.0527 - val_loss: 2.0605
# Epoch 14/100
# 44/44 [==============================] - 8s 192ms/step - loss: 0.1390 - val_loss: 2.8617
# Epoch 15/100
# 44/44 [==============================] - 9s 196ms/step - loss: 0.0280 - val_loss: 11.6813
# Epoch 16/100
# 44/44 [==============================] - 8s 193ms/step - loss: 0.0644 - val_loss: 2.2777
# Epoch 17/100
# 44/44 [==============================] - 8s 192ms/step - loss: 0.0346 - val_loss: 1.5445
# Epoch 18/100
# 44/44 [==============================] - 9s 195ms/step - loss: 0.0265 - val_loss: 3.3269
# Epoch 19/100
# 44/44 [==============================] - 9s 194ms/step - loss: 0.0358 - val_loss: 66.8536
# Epoch 20/100
# 44/44 [==============================] - 8s 193ms/step - loss: 0.0255 - val_loss: 135.6354
# Epoch 21/100
# 44/44 [==============================] - 9s 194ms/step - loss: 0.0046 - val_loss: 92.5820
# Epoch 22/100
# 44/44 [==============================] - 8s 193ms/step - loss: 6.8085e-04 - val_loss: 55.8440
# Epoch 23/100
# 44/44 [==============================] - 8s 192ms/step - loss: 2.1559e-04 - val_loss: 31.0454
# Epoch 24/100
# 44/44 [==============================] - 9s 194ms/step - loss: 1.2470e-04 - val_loss: 16.1796
# Epoch 25/100
# 44/44 [==============================] - 9s 193ms/step - loss: 1.1455e-04 - val_loss: 9.8615
# Epoch 26/100
# 44/44 [==============================] - 8s 190ms/step - loss: 9.8656e-05 - val_loss: 7.1633
# Epoch 27/100
# 44/44 [==============================] - 9s 195ms/step - loss: 6.8417e-05 - val_loss: 6.1759
# Epoch 28/100
# 44/44 [==============================] - 8s 193ms/step - loss: 7.5309e-05 - val_loss: 5.7644
# Epoch 29/100
# 44/44 [==============================] - 8s 192ms/step - loss: 6.7906e-05 - val_loss: 5.5648
# Epoch 30/100
# 44/44 [==============================] - 8s 191ms/step - loss: 5.4751e-05 - val_loss: 5.4480
# Epoch 31/100
# 44/44 [==============================] - 8s 192ms/step - loss: 4.1338e-05 - val_loss: 4.3063
# Epoch 32/100
# 44/44 [==============================] - 8s 192ms/step - loss: 5.9753e-05 - val_loss: 3.8846
# Epoch 33/100
# 44/44 [==============================] - 8s 193ms/step - loss: 3.9104e-05 - val_loss: 4.2391
# Epoch 34/100
# 44/44 [==============================] - 8s 193ms/step - loss: 3.0881e-05 - val_loss: 4.5521
# Epoch 35/100
# 44/44 [==============================] - 9s 195ms/step - loss: 2.5854e-05 - val_loss: 4.8161
# Epoch 36/100
# 44/44 [==============================] - 8s 194ms/step - loss: 2.9694e-05 - val_loss: 5.0095
# Epoch 37/100
# 44/44 [==============================] - 9s 209ms/step - loss: 2.3051e-05 - val_loss: 5.0951
# Epoch 38/100
# 44/44 [==============================] - 8s 179ms/step - loss: 2.1174e-05 - val_loss: 5.2193
# Epoch 39/100
# 44/44 [==============================] - 8s 181ms/step - loss: 2.5225e-05 - val_loss: 5.2685
# Epoch 40/100
# 44/44 [==============================] - 8s 183ms/step - loss: 1.5874e-05 - val_loss: 5.3434
# Epoch 41/100
# 44/44 [==============================] - 8s 178ms/step - loss: 2.0311e-05 - val_loss: 5.4139
# Epoch 42/100
# 44/44 [==============================] - 8s 181ms/step - loss: 1.5753e-05 - val_loss: 5.4514
# Epoch 43/100
# 44/44 [==============================] - 8s 183ms/step - loss: 1.5075e-05 - val_loss: 5.5288
# Epoch 44/100
# 44/44 [==============================] - 8s 180ms/step - loss: 1.1462e-05 - val_loss: 5.5935
# Epoch 45/100
# 44/44 [==============================] - 8s 181ms/step - loss: 1.5357e-05 - val_loss: 5.2593
# Epoch 46/100
# 44/44 [==============================] - 8s 180ms/step - loss: 1.2260e-05 - val_loss: 5.1758
# Epoch 47/100
# 44/44 [==============================] - 8s 183ms/step - loss: 1.4182e-05 - val_loss: 5.3199
# Epoch 48/100
# 44/44 [==============================] - 8s 182ms/step - loss: 8.8625e-06 - val_loss: 5.4671
# Epoch 49/100
# 44/44 [==============================] - 8s 181ms/step - loss: 1.0339e-05 - val_loss: 5.5646
# Epoch 50/100
# 44/44 [==============================] - 8s 183ms/step - loss: 8.5440e-06 - val_loss: 5.6583
# Epoch 51/100
# 44/44 [==============================] - 8s 180ms/step - loss: 1.2889e-05 - val_loss: 5.6792
# Epoch 52/100
# 44/44 [==============================] - 8s 183ms/step - loss: 1.0785e-05 - val_loss: 5.7070
# Epoch 53/100
# Epoch 79/100
# 44/44 [==============================] - 8s 179ms/step - loss: 3.3452e-06 - val_loss: 6.4337
# Epoch 80/100
# 44/44 [==============================] - 8s 181ms/step - loss: 3.0613e-06 - val_loss: 6.4548
# Epoch 81/100
# 44/44 [==============================] - 8s 180ms/step - loss: 3.0617e-06 - val_loss: 6.4734
# Epoch 82/100
# 44/44 [==============================] - 8s 179ms/step - loss: 2.9863e-06 - val_loss: 6.0906
# Epoch 83/100
# 44/44 [==============================] - 8s 181ms/step - loss: 2.4860e-06 - val_loss: 6.1202
# Epoch 84/100
# 44/44 [==============================] - 8s 180ms/step - loss: 2.3539e-06 - val_loss: 6.2337
# Epoch 85/100
# 44/44 [==============================] - 8s 181ms/step - loss: 1.8432e-06 - val_loss: 6.3391
# Epoch 86/100
# 44/44 [==============================] - 8s 180ms/step - loss: 3.0139e-06 - val_loss: 6.4209
# Epoch 87/100
# 44/44 [==============================] - 8s 181ms/step - loss: 2.2637e-06 - val_loss: 6.5001
# Epoch 88/100
# 44/44 [==============================] - 8s 188ms/step - loss: 4.2986e-06 - val_loss: 6.5354
# Epoch 89/100
# 44/44 [==============================] - 9s 199ms/step - loss: 2.0016e-06 - val_loss: 6.5837
# Epoch 90/100
# 44/44 [==============================] - 8s 193ms/step - loss: 3.2064e-06 - val_loss: 6.5949
# Epoch 91/100
# 44/44 [==============================] - 8s 191ms/step - loss: 3.0588e-06 - val_loss: 6.6148
# Epoch 92/100
# 44/44 [==============================] - 8s 191ms/step - loss: 2.2789e-06 - val_loss: 6.6281
# Epoch 93/100
# 44/44 [==============================] - 8s 191ms/step - loss: 2.6482e-06 - val_loss: 6.6692
# Epoch 94/100
# 44/44 [==============================] - 9s 196ms/step - loss: 1.3868e-06 - val_loss: 6.6966
# Epoch 95/100
# 44/44 [==============================] - 8s 193ms/step - loss: 1.9899e-06 - val_loss: 6.7248
# Epoch 96/100
# 44/44 [==============================] - 8s 191ms/step - loss: 2.5745e-06 - val_loss: 6.7455
# Epoch 97/100
# 44/44 [==============================] - 8s 190ms/step - loss: 1.4845e-06 - val_loss: 6.7728
# Epoch 98/100
# 44/44 [==============================] - 8s 193ms/step - loss: 1.3357e-06 - val_loss: 6.7874
# Epoch 99/100
# 44/44 [==============================] - 9s 201ms/step - loss: 2.3482e-06 - val_loss: 6.6612
# Epoch 100/100
# 44/44 [==============================] - 8s 189ms/step - loss: 9.2308e-07 - val_loss: 6.7016

# %%
classes = le.classes_

result = model.predict(X_test)
y_pred = np.argmax(result, axis = 1)
y_true = np.argmax(y_test, axis = 1)

f, ax = utility.plot_cm(y_true, y_pred, module_path = module_path, class_names = classes, color_index = 5)

f.savefig(figure_path + f'cm_simpleCNN_2class.pdf', bbox_inches='tight')
