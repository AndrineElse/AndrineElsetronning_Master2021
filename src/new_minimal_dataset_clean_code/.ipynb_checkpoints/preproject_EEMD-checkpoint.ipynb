# %% [markdown]
# # Preproject routine

# %%
import numpy as np
import pandas as pd
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
sys.path.insert(1, module_path + '/src')

import utility

sys.path.insert(1, module_path + '/src/models/')
import helper


import librosa
import sktime
from sktime.utils.data_io import load_from_tsfile_to_dataframe
from sklearn.model_selection import train_test_split

from math import ceil

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import librosa
from scipy.stats import skew 


sys.path.insert(1, '/home/andrine/Desktop/tqwt_tools')
from tqwt_tools import DualQDecomposition
from scipy.signal import butter, lfilter
from scipy.fft import fft
from scipy.signal import stft
from scipy.stats import skew, kurtosis
from PyEMD import EEMD
from sklearn.cross_decomposition import PLSRegression

from time import time
import sys
import os
figure_path = module_path + '/figures/small_segment_dataset_plots/'

sys.path.insert(1, module_path + '/src/')

from matplotlib.font_manager import FontProperties
font = FontProperties(fname = module_path + '/src/visualization/CharterRegular.ttf', size = 10, weight = 1000)
font_small = FontProperties(fname = module_path + '/src/visualization/CharterRegular.ttf', size = 8, weight = 1000)
colors = ['#F94144', '#90BE6D', '#577590','#F3722C', '#F8961E', '#F9844A', '#F9C74F', '#43AA8B', '#4D908E', '#277DA1']
colors_opa = ['#F9414466', '#90BE6D66', '#57759066','#F3722C66', '#F8961E66',
              '#F9844A66', '#F9C74F66', '#43AA8B66', '#4D908E66', '#277DA166']

sns.set_palette(sns.color_palette(colors))



def znorm(timeseries):
    mean = np.mean(timeseries)
    sd = np.std(timeseries)
    return (timeseries - mean)/sd

target_rate = 44100
ds_target_rate = 8000

import os
names = []
#files_path = '/home/andrine/Desktop/dataTromso/Hasse413/'
#files_path = '/home/andrine/Desktop/dataTromsoFiltered/allFilteres/'

files_path = module_path + '/data/minimal_dataset/data/'
info = pd.read_csv(module_path + '/data/minimal_dataset/info.csv')

# %% [markdown]
# Defining some helping functions, that will be important when extracting

# %%
def get_features(data, sr):
    sr = sr
    n_mfcc = 30
    ft1 = librosa.feature.mfcc(data, sr = sr, n_mfcc=n_mfcc)
    ft2 = librosa.feature.zero_crossing_rate(data)[0]
    ft3 = librosa.feature.spectral_rolloff(data)[0]
    ft4 = librosa.feature.spectral_centroid(data)[0]
    ft5 = librosa.feature.spectral_contrast(data)[0]
    ft6 = librosa.feature.spectral_bandwidth(data)[0]

    ### Get HOS and simple features 
    ft0_trunc = np.hstack((np.mean(data) , np.std(data), skew(data), np.max(data), np.median(data), np.min(data), utility.get_energy(data), utility.get_entropy(data)))

    ### MFCC features
    ft1_trunc = np.hstack((np.mean(ft1, axis=1), np.std(ft1, axis=1), skew(ft1, axis = 1), np.max(ft1, axis = 1), np.median(ft1, axis = 1), np.min(ft1, axis = 1)))

    ### Spectral Features 
    ft2_trunc = np.hstack((np.mean(ft2), np.std(ft2), skew(ft2), np.max(ft2), np.median(ft2), np.min(ft2)))
    ft3_trunc = np.hstack((np.mean(ft3), np.std(ft3), skew(ft3), np.max(ft3), np.median(ft3), np.min(ft3)))
    ft4_trunc = np.hstack((np.mean(ft4), np.std(ft4), skew(ft4), np.max(ft4), np.median(ft4), np.min(ft4)))
    ft5_trunc = np.hstack((np.mean(ft5), np.std(ft5), skew(ft5), np.max(ft5), np.median(ft5), np.min(ft5)))
    ft6_trunc = np.hstack((np.mean(ft6), np.std(ft6), skew(ft6), np.max(ft6), np.median(ft6), np.max(ft6)))
    return np.hstack((ft0_trunc , ft1_trunc, ft2_trunc, ft3_trunc, ft4_trunc, ft5_trunc, ft6_trunc))


def get_xf(audio, sr):
    duration = float(len(audio)) / sr
    T = 1.0/sr
    N = int(duration / T)
    x = np.linspace(0.0, N*T, N +1 )
    if len(x) != len(audio):
        x = np.linspace(0.0, N*T, N)
    return x

def get_emd_features(audio, sr, n_imfs):
    m_imf = n_imfs
    m_sift = 30
    m_trials = 5

    eemd = EEMD(trials=m_trials)
    eemd.spline_kind="slinear"
    eemd.FIXE = m_sift
    
    x = get_xf(audio, sr)

    eIMFs = eemd.eemd(audio, x, max_imf = m_imf)
    
    features = []
    for imf in eIMFs:
        features.append(get_features(imf, sr))
    return np.hstack(features)

# %% [markdown]
# Obtaining the data correlated with filepath, label and ID

# %% [markdown]
# Cutting the dataset down to 3 classes, and balancing the dataset

# %%
info['label'].value_counts()
# Out:
# wheeze     704
# crackle    582
# normal     554
# Name: label, dtype: int64

# %%
'''indices = np.concatenate([np.where(info['label'] == 'normal')[0],
                          np.where(info['label'] == 'wheeze')[0][:580],
                          np.where(info['label'] == 'crackle')[0]])'''

indices = np.concatenate([np.where(info['label'] == 'wheeze')[0][:580],
                          np.where(info['label'] == 'crackle')[0]])


info = info.iloc[indices]

# %% [markdown]
# ### Making unbiased train, test, val splits

# %%
from sklearn.model_selection import train_test_split

info.sort_values(by=['patient_id'], inplace=True)


id_unique = info['patient_id'].unique()

id_train , id_test = train_test_split(id_unique, test_size=0.2, random_state=42)
id_train , id_val = train_test_split(id_unique, test_size=0.25, random_state=42)

def get_indices(id_list, data):
    indices = np.array([])
    for i in id_list:
        idx = np.where(data['patient_id'] == i)[0]
        indices = np.append([list(idx)] , [indices])
        
    return indices


indices_train = get_indices(id_train, info).astype(int)
indices_test = get_indices(id_test, info).astype(int)
indices_val = get_indices(id_val, info).astype(int)

print(info.iloc[indices_train]['label'].value_counts())
# Out:
# wheeze     441
# crackle    426
# Name: label, dtype: int64

# %%
def get_data_array(data):
    error_in_data = {}
    count = 0
    
    X = []
    y = []
    for row in data.iterrows():
        audio_file = row[1]['filepath_new']
        label = row[1]['label']

        try:
            sr, audio = utility.read_wav_file(audio_file, 8000)

        except EOFError as error:
            error_in_data[audio_file] = 'EOFError'
            continue

        try:
            #audio = znorm(audio)
            #features = get_features(audio, sr)
            features = get_emd_features(audio, sr, 5)
            if len(features)!= 1308:
                print('Not long enough')
                continue
            X.append(features)
            y.append(label)
            
            count = count + 1
            print(f'Features extracted from : {count} of {len(data)}')

        except ValueError as error:
            error_in_data[audio_file] = 'ValueError'
            continue
    return (np.array(X), pd.Series(y))


indices = {
    'train' : indices_train,
    'test' : indices_test,
    'val' : indices_val
    
}

result_datasets = {
    'train' : ([], []),
    'test' : ([], []),
    'val' : ([], [])
    
}

for name, i in indices.items():
    result_datasets[name] = get_data_array(info.iloc[i])

X_train, y_train = result_datasets['train']
X_test, y_test = result_datasets['test']
X_val, y_val = result_datasets['val']
# Out:
# Features extracted from : 1 of 867
# Features extracted from : 2 of 867
# Features extracted from : 3 of 867
# Features extracted from : 4 of 867
# Features extracted from : 5 of 867
# Features extracted from : 6 of 867
# Features extracted from : 7 of 867
# Features extracted from : 8 of 867
# Features extracted from : 9 of 867
# Features extracted from : 10 of 867
# Features extracted from : 11 of 867
# Features extracted from : 12 of 867
# Features extracted from : 13 of 867
# Features extracted from : 14 of 867
# Features extracted from : 15 of 867
# Features extracted from : 16 of 867
# Features extracted from : 17 of 867
# Features extracted from : 18 of 867
# Features extracted from : 19 of 867
# Features extracted from : 20 of 867
# Features extracted from : 21 of 867
# Features extracted from : 22 of 867
# Features extracted from : 23 of 867
# Features extracted from : 24 of 867
# Features extracted from : 25 of 867
# Features extracted from : 26 of 867
# Features extracted from : 27 of 867
# Features extracted from : 28 of 867
# Features extracted from : 29 of 867
# Features extracted from : 30 of 867
# Features extracted from : 31 of 867
# Features extracted from : 32 of 867
# Features extracted from : 33 of 867
# Features extracted from : 34 of 867
# Features extracted from : 35 of 867
# Features extracted from : 36 of 867
# Features extracted from : 37 of 867
# Features extracted from : 38 of 867
# Features extracted from : 39 of 867
# Features extracted from : 40 of 867
# Features extracted from : 41 of 867
# Features extracted from : 42 of 867
# Features extracted from : 43 of 867
# Features extracted from : 44 of 867
# Features extracted from : 45 of 867
# Features extracted from : 46 of 867
# Features extracted from : 47 of 867
# Features extracted from : 48 of 867
# Features extracted from : 49 of 867
# Features extracted from : 50 of 867
# Features extracted from : 51 of 867
# Features extracted from : 52 of 867
# Features extracted from : 53 of 867
# Features extracted from : 54 of 867
# Features extracted from : 55 of 867
# Features extracted from : 56 of 867
# Features extracted from : 57 of 867
# Features extracted from : 58 of 867
# Features extracted from : 59 of 867
# Features extracted from : 60 of 867
# Features extracted from : 61 of 867
# Features extracted from : 62 of 867
# Features extracted from : 63 of 867
# Features extracted from : 64 of 867
# Features extracted from : 65 of 867
# Features extracted from : 66 of 867
# Features extracted from : 67 of 867
# Features extracted from : 68 of 867
# Features extracted from : 69 of 867
# Features extracted from : 70 of 867
# Features extracted from : 71 of 867
# Features extracted from : 72 of 867
# Features extracted from : 73 of 867
# Features extracted from : 74 of 867
# Features extracted from : 75 of 867
# Features extracted from : 76 of 867
# Features extracted from : 77 of 867
# Features extracted from : 78 of 867
# Features extracted from : 79 of 867
# Features extracted from : 80 of 867
# Features extracted from : 81 of 867
# Features extracted from : 82 of 867
# Features extracted from : 83 of 867
# Features extracted from : 84 of 867
# Features extracted from : 85 of 867
# Features extracted from : 86 of 867
# Features extracted from : 87 of 867
# Features extracted from : 88 of 867
# Features extracted from : 89 of 867
# Features extracted from : 90 of 867
# Features extracted from : 91 of 867
# Features extracted from : 92 of 867
# Features extracted from : 93 of 867
# Features extracted from : 94 of 867
# Features extracted from : 217 of 295
# Features extracted from : 218 of 295
# Features extracted from : 219 of 295
# Features extracted from : 220 of 295
# Features extracted from : 221 of 295
# Features extracted from : 222 of 295
# Features extracted from : 223 of 295
# Features extracted from : 224 of 295
# Features extracted from : 225 of 295
# Features extracted from : 226 of 295
# Features extracted from : 227 of 295
# Features extracted from : 228 of 295
# Features extracted from : 229 of 295
# Features extracted from : 230 of 295
# Features extracted from : 231 of 295
# Features extracted from : 232 of 295
# Features extracted from : 233 of 295
# Features extracted from : 234 of 295
# Features extracted from : 235 of 295
# Features extracted from : 236 of 295
# Features extracted from : 237 of 295
# Features extracted from : 238 of 295
# Features extracted from : 239 of 295
# Features extracted from : 240 of 295
# Features extracted from : 241 of 295
# Features extracted from : 242 of 295
# Features extracted from : 243 of 295
# Features extracted from : 244 of 295
# Features extracted from : 245 of 295
# Features extracted from : 246 of 295
# Features extracted from : 247 of 295
# Features extracted from : 248 of 295
# Features extracted from : 249 of 295
# Features extracted from : 250 of 295
# Features extracted from : 251 of 295
# Features extracted from : 252 of 295
# Features extracted from : 253 of 295
# Features extracted from : 254 of 295
# Features extracted from : 255 of 295
# Features extracted from : 256 of 295
# Features extracted from : 257 of 295
# Features extracted from : 258 of 295
# Features extracted from : 259 of 295
# Features extracted from : 260 of 295
# Features extracted from : 261 of 295
# Features extracted from : 262 of 295
# Features extracted from : 263 of 295
# Features extracted from : 264 of 295
# Features extracted from : 265 of 295
# Features extracted from : 266 of 295
# Features extracted from : 267 of 295
# Features extracted from : 268 of 295
# Features extracted from : 269 of 295
# Features extracted from : 270 of 295
# Features extracted from : 271 of 295
# Features extracted from : 272 of 295
# Features extracted from : 273 of 295
# Features extracted from : 274 of 295
# Features extracted from : 275 of 295
# Features extracted from : 276 of 295
# Features extracted from : 277 of 295
# Features extracted from : 278 of 295
# Features extracted from : 279 of 295
# Features extracted from : 280 of 295
# Features extracted from : 281 of 295
# Features extracted from : 282 of 295
# Features extracted from : 283 of 295
# Features extracted from : 284 of 295
# Features extracted from : 285 of 295
# Features extracted from : 286 of 295
# Features extracted from : 287 of 295
# Features extracted from : 288 of 295
# Features extracted from : 289 of 295
# Features extracted from : 290 of 295
# Features extracted from : 291 of 295
# Features extracted from : 292 of 295
# Features extracted from : 293 of 295
# Features extracted from : 294 of 295
# Features extracted from : 295 of 295

# %%
file_splits = {
    '/features/extracted_ts_files/minimal_dataset_2class__preprojectEEMD_TRAIN.ts' : (X_train, y_train),
    '/features/extracted_ts_files/minimal_dataset_2class__preprojectEEMD_TEST.ts' : (X_test, y_test),
    '/features/extracted_ts_files/minimal_dataset_2class__preprojectEEMD_VAL.ts' : (X_val, y_val)
}


def write_feature_extracted_dataset_to_ts(filename, X,y):

    w = open(module_path + filename, 'w+')
    row = w.read()

    w.write('@problemName Minimal UiT Lung Sound \n')
    w.write('@timeStamps false \n')
    w.write('@missing false \n')
    w.write('@univariate true \n')
    w.write('@equalLength true \n')
    w.write('@classLabel true crackle wheeze \n')
    w.write('@data \n')

    error_in_data = {}
    count = 0
    for idx, row in enumerate(X):
        label = y[idx]

        try:
            new_row = str(list(row))[1:-1].replace(' ', '') + ':' + label + '\n'
            w.write(new_row)


        except ValueError as error:
            error_in_data[audio_file] = 'ValueError'
            continue
             
for name, i in file_splits.items():
    write_feature_extracted_dataset_to_ts(name, i[0], i[1])

# %% [markdown]
# # Testing classification
#
# ## Preproject dataset, with EEMD

# %%
from sktime.utils.data_processing import from_nested_to_2d_array

X_train, y_train = load_from_tsfile_to_dataframe(module_path + '/features/extracted_ts_files/minimal_dataset_3class__preprojectEEMD_TRAIN.ts')
X_test, y_test = load_from_tsfile_to_dataframe(module_path + '/features/extracted_ts_files/minimal_dataset_3class__preprojectEEMD_TEST.ts')
X_val, y_val = load_from_tsfile_to_dataframe(module_path + '/features/extracted_ts_files/minimal_dataset_3class__preprojectEEMD_VAL.ts')


X_train = from_nested_to_2d_array(X_train)
X_test = from_nested_to_2d_array(X_test)
X_val = from_nested_to_2d_array(X_val)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

class_names =  list(pd.factorize(y_train)[1])
clf = RandomForestClassifier(criterion='entropy', max_depth=8, n_estimators=500,random_state=42)

#clf = SVC(C=100, gamma=0.1)

clf.fit(X_train , y_train)
y_pred = clf.predict(X_test)

f, ax = utility.plot_cm(y_test, y_pred, module_path = module_path, class_names = class_names, color_index = 1)

f.savefig(figure_path + f'cm_preprojectEEMD_3class_rf.pdf', bbox_inches='tight')

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      crackle       0.57      0.68      0.62       111
#       normal       0.45      0.46      0.45       105
#       wheeze       0.53      0.43      0.47       128
#
#     accuracy                           0.52       344
#    macro avg       0.52      0.52      0.52       344
# weighted avg       0.52      0.52      0.52       344

# %%
from sktime.utils.data_processing import from_nested_to_2d_array

X_train, y_train = load_from_tsfile_to_dataframe(module_path + '/features/extracted_ts_files/minimal_dataset_2class__preprojectEEMD_TRAIN.ts')
X_test, y_test = load_from_tsfile_to_dataframe(module_path + '/features/extracted_ts_files/minimal_dataset_2class__preprojectEEMD_TEST.ts')
X_val, y_val = load_from_tsfile_to_dataframe(module_path + '/features/extracted_ts_files/minimal_dataset_2class__preprojectEEMD_VAL.ts')


X_train = from_nested_to_2d_array(X_train)
X_test = from_nested_to_2d_array(X_test)
X_val = from_nested_to_2d_array(X_val)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

class_names =  list(pd.factorize(y_train)[1])
clf = RandomForestClassifier(criterion='entropy', max_depth=8, n_estimators=500,random_state=42)

#clf = SVC(C=100, gamma=0.1)

clf.fit(X_train , y_train)
y_pred = clf.predict(X_test)

f, ax = utility.plot_cm(y_test, y_pred, module_path = module_path, class_names = class_names, color_index = 1)

f.savefig(figure_path + f'cm_preprojectEEMD_2class_rf.pdf', bbox_inches='tight')

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      crackle       0.76      0.76      0.76       123
#       wheeze       0.74      0.74      0.74       114
#
#     accuracy                           0.75       237
#    macro avg       0.75      0.75      0.75       237
# weighted avg       0.75      0.75      0.75       237

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
le.fit(y_train)
y_train_ = le.transform(y_train)

pls2 = PLSRegression(n_components=2)
p2 = pls2.fit_transform(X_train, y_train_)
f, ax = helper.scatterplot_with_colors(p2[0], y_train_,
                                       module_path, new_legends = le.classes_,
                                       x_y_labels = ['PLSR1', 'PLSR2'])

plt.show()

f.savefig(figure_path + f'PLSR_preprojectEEMD_2class.pdf', bbox_inches='tight')

# %% [markdown]
# ## Preproject , without EEMD

# %%
from sktime.utils.data_processing import from_nested_to_2d_array

X_train, y_train = load_from_tsfile_to_dataframe(module_path + '/features/extracted_ts_files/minimal_dataset_3class__preproject_TRAIN.ts')
X_test, y_test = load_from_tsfile_to_dataframe(module_path + '/features/extracted_ts_files/minimal_dataset_3class__preproject_TEST.ts')
X_val, y_val = load_from_tsfile_to_dataframe(module_path + '/features/extracted_ts_files/minimal_dataset_3class__preproject_VAL.ts')


X_train = from_nested_to_2d_array(X_train)
X_test = from_nested_to_2d_array(X_test)
X_val = from_nested_to_2d_array(X_val)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

class_names =  list(pd.factorize(y_train)[1])
clf = RandomForestClassifier(criterion='entropy', max_depth=8, n_estimators=500,random_state=42)

#clf = SVC(C=100, gamma=0.1)

clf.fit(X_train , y_train)
y_pred = clf.predict(X_test)

f, ax = utility.plot_cm(y_test, y_pred, module_path = module_path, class_names = class_names, color_index = 0)

f.savefig(figure_path + f'cm_preproject_3class_rf.pdf', bbox_inches='tight')

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      crackle       0.56      0.65      0.60       111
#       normal       0.52      0.41      0.46       105
#       wheeze       0.62      0.64      0.63       128
#
#     accuracy                           0.57       344
#    macro avg       0.57      0.57      0.56       344
# weighted avg       0.57      0.57      0.57       344

# %%
from sktime.utils.data_processing import from_nested_to_2d_array

X_train, y_train = load_from_tsfile_to_dataframe(module_path + '/features/extracted_ts_files/minimal_dataset_2class__preproject_TRAIN.ts')
X_test, y_test = load_from_tsfile_to_dataframe(module_path + '/features/extracted_ts_files/minimal_dataset_2class__preproject_TEST.ts')
X_val, y_val = load_from_tsfile_to_dataframe(module_path + '/features/extracted_ts_files/minimal_dataset_2class__preproject_VAL.ts')


X_train = from_nested_to_2d_array(X_train)
X_test = from_nested_to_2d_array(X_test)
X_val = from_nested_to_2d_array(X_val)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

class_names =  list(pd.factorize(y_train)[1])
clf = RandomForestClassifier(criterion='entropy', max_depth=8, n_estimators=500,random_state=42)

#clf = SVC(C=100, gamma=0.1)

clf.fit(X_train , y_train)
y_pred = clf.predict(X_test)

f, ax = utility.plot_cm(y_test, y_pred, module_path = module_path, class_names = class_names, color_index = 0)

f.savefig(figure_path + f'cm_preproject_2class_rf.pdf', bbox_inches='tight')

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      crackle       0.82      0.84      0.83       123
#       wheeze       0.82      0.80      0.81       114
#
#     accuracy                           0.82       237
#    macro avg       0.82      0.82      0.82       237
# weighted avg       0.82      0.82      0.82       237

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
le.fit(y_train)
y_train_ = le.transform(y_train)

pls2 = PLSRegression(n_components=2)
p2 = pls2.fit_transform(X_train, y_train_)
f, ax = helper.scatterplot_with_colors(p2[0], y_train_,
                                       module_path, new_legends = le.classes_,
                                       x_y_labels = ['PLSR1', 'PLSR2'])

plt.show()

f.savefig(figure_path + f'PLSR_preproject_2class.pdf', bbox_inches='tight')
