# %%
module_path
# Out:
# '/home/andrine/Desktop/AndrineElsetronning_Master2021'

# %%
import matplotlib.pyplot as plt
import sys
import os
module_path = os.path.abspath(os.path.join('../..'))
sys.path.insert(1, module_path + '/src')
import utility
import numpy as np

c_path = module_path + '/data/crackleWheeze/crackle/'
c_names = os.listdir(c_path) 
TARGET_RATE = 40000

# %%
sr, y = utility.read_wav_file(c_path + c_names[10], TARGET_RATE)
y = utility.denoise_audio(y)
y, sr = utility.downsample(y, sr, 4000)
t = utility.get_t(y,sr)

# %%
plt.plot(t,y)

# %%
yf = np.fft.fft(y)
plt.plot(yf[1:-1])
# Out:
# /home/andrine/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
yf
# Out:
# array([ 21.33910989+2.46469511e-14j,  14.15426263-1.92015968e+01j,
#         52.74047088+2.04862922e+01j, ..., -23.57262778+3.40001914e+00j,
#         52.74047088-2.04862922e+01j,  14.15426263+1.92015968e+01j])
