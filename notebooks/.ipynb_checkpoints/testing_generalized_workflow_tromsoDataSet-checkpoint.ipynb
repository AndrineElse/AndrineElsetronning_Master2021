# %% [markdown]
# # Notebook for testing and exploring the generalized workflow for feature extraction

# %%
import sys
import os
import pandas as pd
import numpy as np

module_path = os.path.abspath(os.path.join('..'))

sys.path.insert(1, module_path + '/src')
import audio_time_series_classification as preproject
import utility

sys.path.insert(1, module_path + '/src/models/')
import helper

from sklearn.decomposition import PCA
from sktime.utils.data_io import load_from_tsfile_to_dataframe
from sklearn.feature_selection import SelectKBest, chi2
from sktime.utils.data_processing import from_nested_to_2d_array
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
import matplotlib.pyplot as plt
from sklearn.cross_decomposition import PLSRegression

figure_path = module_path + '/figures/'

# %% [markdown]
# # Preproject method with Lung Sound (kaggle)

# %%
ts_path = module_path + '/data/ts_files/crackleNoCrackle_FULL.ts'
#NB ! This file has already been downsampled and denoised before saving
kwargs_ls = {
    'ts_file_path': ts_path,
    'sr' : 8000,
    'UCR_file': False,
    'n_mfcc' : 30,
    'denoise' : False,
    'downsample' : False,
    'downsample_new_sr' : 8000,
    'update' : False,
    'name' : 'lungsound',
    'module_path' : module_path
}

ls = preproject.overproduced_audio_time_series_features(**kwargs_ls)

# %%
X_train, X_test, y_train, y_test = ls.get_X_y_transformed(train_test_split = True)

# %%
pls2 = PLSRegression(n_components=2)
p2 = pls2.fit_transform(X_train, y_train)
f, ax = helper.scatterplot_with_colors(p2[0], y_train.values.astype(int),
                                       module_path, new_legends = ['no crackle', 'crackle'],
                                       x_y_labels = ['PLSR1', 'PLSR2'])

plt.show()

f.savefig(figure_path + f'PLSR_preproject_lung.pdf', bbox_inches='tight')

# %% [markdown]
# # Minirocket testing

# %%
le = preprocessing.LabelEncoder()

X_train, y_train = load_from_tsfile_to_dataframe(module_path + '/features/extracted_features_ts_files/lungsound_MiniROCKET_TRAIN.ts')
X_test, y_test = load_from_tsfile_to_dataframe(module_path + '/features/extracted_features_ts_files/lungsound_MiniROCKET_TEST.ts')
le.fit(y_train)
y_train = le.transform(y_train)
y_test = le.transform(y_test)

X_train = from_nested_to_2d_array(X_train)
X_test = from_nested_to_2d_array(X_test)

X_train.columns = np.arange(len(X_train.columns))
X_test.columns = np.arange(len(X_test.columns))


y_train = pd.Series(y_train)
y_test = pd.Series(y_test)

'''
k = 200
select = SelectKBest(chi2, k=k)
X_train_s = select.fit(X_train, y_train)
indices = select.get_support(indices = True)
X_test = X_test[indices]
X_train = X_train[indices]

'''
# Out:
# '\nk = 200\nselect = SelectKBest(chi2, k=k)\nX_train_s = select.fit(X_train, y_train)\nindices = select.get_support(indices = True)\nX_test = X_test[indices]\nX_train = X_train[indices]\n\n'

# %%
pls2 = PLSRegression(n_components=2)
p2 = pls2.fit_transform(X_train, y_train)
f, ax = helper.scatterplot_with_colors(p2[0], y_train.values.astype(int),
                                       module_path, new_legends = ['no crackle', 'crackle'],
                                       x_y_labels = ['PLSR1', 'PLSR2'])

plt.show()

f.savefig(figure_path + f'PLSR_minirocket_lung.pdf', bbox_inches='tight')

# %% [markdown]
# ### Dimentionality reduction using PCA

# %%
pca = PCA(n_components = 100)
pca.fit(X_train)
exp_var_cumul = np.cumsum(pca.explained_variance_ratio_)

plt.plot(exp_var_cumul)

# %%
pca = PCA(n_components = 100)

pca.fit(X_train)
X_train = pca.transform(X_train)
X_test = pca.transform(X_test)

# %% [markdown]
# ### Balancing the dataset

# %%
y_train.value_counts()
# Out:
# 0    3241
# 1    1757
# dtype: int64

# %%
indices_0 = np.where(y_train.astype(int) == 0)[0]
indices_1 = np.where(y_train.astype(int) == 1)[0]
indices = np.concatenate((indices_0[0:1757], indices_1))

# %% [markdown]
# ### Plotting the performance
#
# Here a Gaussian Process classifier is utilized. This works well because we want a problibalistic classifier

# %%
kernel = 1.0 * RBF(1.0)
gpc = GaussianProcessClassifier(kernel=kernel,random_state=0, n_jobs = -3)
gpc.fit(X_train[indices],y_train[indices])
pred = gpc.predict(X_test)

f, ax = utility.plot_cm(y_test, pred, module_path = module_path, class_names = ['no crackle', 'crackle'])

plt.show()

#f.savefig(figure_path + f'lung_minirocket_cm.pdf', bbox_inches='tight')

# %% [markdown]
# # Doing some tests on other datasets

# %%
name_UCR = 'BinaryHeartbeat'

# Code below is to fix the issue that this dataset does not have .ts files yet 
ts_path = f'/home/andrine/anaconda3/lib/python3.7/site-packages/sktime/datasets/data/{name_UCR}'


kwargs_hs = {
    'ts_file_path': ts_path,
    'sr' : 2000,
    'UCR_file': True,
    'n_mfcc' : 30,
    'denoise' : False,
    'downsample' : False,
    'downsample_new_sr' : 4000,
    'update' : True
}

hs = preproject.overproduced_audio_time_series_features(**kwargs_hs)

# %%
from sklearn.naive_bayes import GaussianNB

from sklearn.preprocessing import MinMaxScaler


scaler = MinMaxScaler() 
scaler.fit(X_train)
X_train = pd.DataFrame(scaler.transform(X_train)) 
X_test = pd.DataFrame(scaler.transform(X_test)) 

clf = GaussianNB().fit(X_train, y_train)
y_pred = clf.predict(X_test)

f, ax = utility.plot_cm(y_test, y_pred, module_path = module_path)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']} 
  
#grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)
#grid.fit(X_train, y_train)

# %%
clf = SVC(**{'C': 10, 'gamma': 1, 'kernel': 'rbf', 'probability' : True}).fit(X_train, y_train)

# %%
y_pred = clf.predict(X_test)
prob = clf.predict_proba(X_test)

f, ax = utility.plot_cm(y_test, y_pred, module_path = module_path)

# %%
from sklearn.metrics import accuracy_score, f1_score

def get_accuracy_accuracy_rejection_curve(y_test, y_pred, prob):  
    tot = len(y_test)
    def is_in_range(l, u, x):
        return (x < u) & (x > l)
    
    lower = np.linspace(0.5, 0, 101)[:-1]
    upper = np.linspace(0.5, 1, 101)[:-1]
    
    
    acc = []
    re = []
    

    for r in zip(lower, upper):
        temp_true = y_test.copy()
        temp_pred = y_pred.copy()
        
        reject_samples = is_in_range(r[0], r[1], prob)
        
        if np.any(reject_samples):
            keep_indices = np.where(reject_samples !=  True)[0]
            keep_indices = np.unique(keep_indices)

            temp_true = temp_true[keep_indices]
            temp_pred = temp_pred[keep_indices]
            
        if len(acc)%10 == 0:
            f, ax = utility.plot_cm(temp_true, temp_pred, module_path = module_path)
            
        acc.append(accuracy_score(temp_true, temp_pred))
        re.append(1 - len(temp_true)/tot)
        
    return acc, re

# %%
a, r = get_accuracy_accuracy_rejection_curve(y_test, y_pred, prob)

# %%
plt.plot(r, a)
